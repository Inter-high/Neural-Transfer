# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from torchvision.models import vgg19, VGG19_Weights
from skimage.color import rgb2lab, lab2rgb

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

# %% [markdown]
# # 1. data

# %% [markdown]
# ## 1.1. load images

# %%
style_img_path = "./notebook_images/picasso.jpg"
content_img_path = "./notebook_images/dancing.jpg"

style_img = Image.open(style_img_path)
content_img = Image.open(content_img_path)

# %% [markdown]
# ## 1.2. transform as tensor

# %%
img_size = 512 if torch.cuda.is_available() else 128

transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
])

style_tensor = transform(style_img).unsqueeze(0)
content_tensor = transform(content_img).unsqueeze(0)

print(f"style_tensor shpae: {style_tensor.shape}")
print(f"content_tensor shpae: {content_tensor.shape}")
# Out:
# style_tensor shpae: torch.Size([1, 3, 128, 128])
# content_tensor shpae: torch.Size([1, 3, 128, 128])

# %% [markdown]
# ## 1.3. make noise tensor

# %%
noise_tensor = torch.randn(style_tensor.size())
print(f"noise_tensor shpae: {noise_tensor.shape}")
# Out:
# noise_tensor shpae: torch.Size([1, 3, 128, 128])

# %% [markdown]
# ## 1.4. visualize

# %%
untransform = transforms.Compose([
    transforms.ToPILImage(),
])

# %%
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.imshow(untransform(style_tensor.squeeze(0)))
plt.title(f"original style_img")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(untransform(content_tensor.squeeze(0)))
plt.title(f"original content_img")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(untransform(noise_tensor.squeeze(0)))
plt.title(f"original noise_img")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. model

# %% [markdown]
# ## 2.1. load pre-trained vgg19

# %%
vgg19_model = vgg19(weights=VGG19_Weights.DEFAULT).features.eval()

# %% [markdown]
# ## 2.2. add normalization layer

# %%
ImageNet_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
ImageNet_std = torch.tensor([0.229, 0.224, 0.225]).to(device)

class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        self.mean = mean.view(-1, 1, 1)
        self.std = std.view(-1, 1, 1)

    def forward(self, img):
        return (img - self.mean) / self.std

# %% [markdown]
# ## 2.3. slice vgg19

# %%
model = nn.Sequential(Normalization(ImageNet_mean, ImageNet_std))
i = 0
for layer in vgg19_model.children():
    if isinstance(layer, nn.Conv2d):
        i += 1
        name = f"conv_{i}"
    elif isinstance(layer, nn.ReLU):
        layer = nn.ReLU(inplace=False) # inplace=True <- backprop error
        name = f"relu_{i}"
    elif isinstance(layer, nn.MaxPool2d):
        layer = nn.AvgPool2d(2, 2) # follow the paper
        name = f"pool_{i}"
    elif isinstance(layer, nn.BatchNorm2d):
        name = f"bn_{i}"

    model.add_module(name, layer)

    if name == f'conv_5':
        break

print(model)
# Out:
# Sequential(
#   (0): Normalization()
#   (conv_1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu_1): ReLU()
#   (conv_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu_2): ReLU()
#   (pool_2): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv_3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu_3): ReLU()
#   (conv_4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu_4): ReLU()
#   (pool_4): AvgPool2d(kernel_size=2, stride=2, padding=0)
#   (conv_5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# ## 2.4. visualize

# %%
def visualize_feature_maps(style_results, content_results, noise_results, 
                           layers=['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5'], title=""):
    fig, axes = plt.subplots(len(layers), 3, figsize=(15, 5 * len(layers)))
    fig.suptitle(title, fontsize=16)

    if len(layers) == 1:
        axes = [axes]

    for i, layer in enumerate(layers):
        # Style feature map
        style_feature_map = style_results[layer].squeeze(0).cpu()
        style_mean_map = torch.mean(style_feature_map, dim=0).detach().numpy()
        axes[i][0].imshow(style_mean_map, cmap="viridis")
        axes[i][0].set_title(f"{layer} (Style)")
        axes[i][0].axis("off")

        # Content feature map
        content_feature_map = content_results[layer].squeeze(0).cpu()
        content_mean_map = torch.mean(content_feature_map, dim=0).detach().numpy()
        axes[i][1].imshow(content_mean_map, cmap="viridis")
        axes[i][1].set_title(f"{layer} (Content)")
        axes[i][1].axis("off")

        # Noise feature map
        noise_feature_map = noise_results[layer].squeeze(0).cpu()
        noise_mean_map = torch.mean(noise_feature_map, dim=0).detach().numpy()
        axes[i][2].imshow(noise_mean_map, cmap="viridis")
        axes[i][2].set_title(f"{layer} (Noise)")
        axes[i][2].axis("off")

    plt.tight_layout(rect=[0, 0, 1, 0.96])
    plt.show()

# %%
model.eval()

style_feature_map = style_tensor.clone().to(device)
content_feature_map = content_tensor.clone().to(device)
noise_feature_map = noise_tensor.clone().to(device)

style_feature_maps = {}
content_feature_maps = {}
noise_feature_maps = {}

for name, layer in model.named_children():
    style_feature_map = layer(style_feature_map)
    style_feature_maps[name] = style_feature_map

    content_feature_map = layer(content_feature_map)
    content_feature_maps[name] = content_feature_map

    noise_feature_map = layer(noise_feature_map)
    noise_feature_maps[name] = noise_feature_map

# %%
visualize_feature_maps(style_feature_maps, content_feature_maps, noise_feature_maps, title="Before Training: Style vs Content vs Noise Feature Maps")

# %% [markdown]
# # 3. loss

# %% [markdown]
# ## 3.1. style-loss

# %% [markdown]
# ## Gram Matrix 비유: 페인팅
#
# ### 페인트의 색상과 질감(채널)
# - 화가가 그림을 그릴 때 사용한 다양한 **색상과 질감**이 그림의 스타일을 결정합니다.
# - 피처맵의 각 채널은 그림의 특정 **색상이나 질감**을 표현한다고 생각할 수 있습니다.
#
# ### 색상 간의 관계
# - 스타일은 단순히 어떤 색상이 쓰였는지가 아니라, **색상들 간의 관계와 조화**에서 나옵니다.
# - 예를 들어:
#   - **파란색과 노란색**이 부드럽게 섞이면 차분한 스타일.
#   - **빨간색과 검은색**이 강하게 대조되면 강렬한 스타일.
# - Gram Matrix는 이러한 **색상 간의 상관관계**를 수치적으로 캡처합니다.
#
# ### 그림의 위치 정보 제거
# - 스타일은 그림의 구체적인 **위치**와 상관없이, 색상과 질감의 전반적인 **조화**로 정의됩니다.
# - Gram Matrix는 위치 정보(공간적 구조)를 무시하고, 스타일의 본질인 **조화와 패턴**만 남깁니다.

# %%
def gram_matrix(feature_map):
    batch, channel, height, width = feature_map.size()

    features = feature_map.view(batch * channel, height * width)
    G = torch.mm(features, features.t())

    return G.div(batch * channel * height * width)

# %%
def style_loss(input, target):
    input_G = gram_matrix(input)
    target_G = gram_matrix(target)

    loss = F.mse_loss(input_G, target_G)

    return loss

# %% [markdown]
# ## 3.2. content-loss

# %%
def content_loss(input, target):
    return F.mse_loss(input, target)

# %% [markdown]
# # 4. train

# %% [markdown]
# ## 4.1. training

# %%
model.eval()

style_feature_map = style_tensor.clone().to(device)
content_feature_map = content_tensor.clone().to(device)

style_feature_maps = {}
content_feature_maps = {}

for name, layer in model.named_children():
    style_feature_map = layer(style_feature_map)
    style_feature_maps[name] = style_feature_map

    content_feature_map = layer(content_feature_map)
    content_feature_maps[name] = content_feature_map

# %%
style_layers = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']
content_layers = ['conv_4']


def train(model, style_feature_maps, content_feature_maps, epochs=300, style_weight=1000000, content_weight=1):
    required_noise_feature_map = noise_tensor.clone()
    required_noise_feature_map.requires_grad_(True)

    model.eval()
    model.requires_grad_(False)

    optimizer = optim.LBFGS([required_noise_feature_map])
    epoch = 0

    def closure():
        nonlocal epoch  # epoch을 closure 내부에서 수정 가능하도록 선언
        with torch.no_grad():
            required_noise_feature_map.clamp_(0, 1)
        output = required_noise_feature_map

        optimizer.zero_grad()
        style_losses = 0.0
        content_losses = 0.0
        for name, layer in model.named_children():
            output = layer(output)

            if name in style_layers:
                style_losses += style_loss(output, style_feature_maps[name].detach())
            
            if name in content_layers:
                content_losses += content_loss(output, content_feature_maps[name].detach())
        
        style_losses *= style_weight
        content_losses *= content_weight

        loss = style_losses + content_losses
        loss.backward()

        epoch += 1
        if epoch % 50 == 0:
            print(f"epoch {epoch}/{epochs}:")
            print(f"style-loss: {style_losses.item():.4f} content-loss: {content_losses.item():.4f}")
            print()

        return loss

    while epoch <= epochs:
        optimizer.step(closure)

    with torch.no_grad():
        required_noise_feature_map.clamp_(0, 1)

    return required_noise_feature_map

required_noise_feature_map = train(model, style_feature_maps, content_feature_maps)
# Out:
# epoch 50/300:
# style-loss: 3.0012 content-loss: 8.5631
#
# epoch 100/300:
# style-loss: 1.0300 content-loss: 4.9224
#
# epoch 150/300:
# style-loss: 0.6866 content-loss: 3.5918
#
# epoch 200/300:
# style-loss: 0.5477 content-loss: 3.0656
#
# epoch 250/300:
# style-loss: 0.4903 content-loss: 2.8761
#
# epoch 300/300:
# style-loss: 0.4659 content-loss: 2.7848

# %% [markdown]
# ## 4.2. visualize

# %%
noise_feature_map = required_noise_feature_map
noise_feature_maps = {}

for name, layer in model.named_children():
    noise_feature_map = layer(noise_feature_map)
    noise_feature_maps[name] = noise_feature_map

# %%
visualize_feature_maps(style_feature_maps, content_feature_maps, noise_feature_maps, title="After Training: Style vs Content vs Noise Feature Maps")

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(untransform(noise_tensor.squeeze(0)))
plt.title("Before Trainig: noise_img")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(untransform(required_noise_feature_map.squeeze(0)))
plt.title("After Trainig: noise_img")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Postprocess

# %% [markdown]
# ## 5.1. transform as ndarray

# %%
trained_img = np.array(untransform(required_noise_feature_map.squeeze(0))).astype(np.uint8)
content_img = np.array(untransform(content_tensor.squeeze(0)))

# %%
print(f"trained_img dtype: {trained_img.dtype}")
print(f"trained_img nanmin: {np.nanmin(trained_img)}")
print(f"trained_img nanmax: {np.nanmax(trained_img)}")

print(f"content_img dtype: {content_img.dtype}")
print(f"content_img nanmin: {np.nanmin(content_img)}")
print(f"content_img nanmax: {np.nanmax(content_img)}")
# Out:
# trained_img dtype: uint8
# trained_img nanmin: 0
# trained_img nanmax: 254
# content_img dtype: uint8
# content_img nanmin: 1
# content_img nanmax: 252

# %% [markdown]
# ## 5.2. normalize 0~1

# %%
trained_img = trained_img / 255.0 if np.max(trained_img) > 1 else trained_img
content_img = content_img / 255.0 if np.max(content_img) > 1 else content_img

# %% [markdown]
# ## 5.3. transform as Lab

# %%
trained_lab = rgb2lab(trained_img)
content_lab = rgb2lab(content_img)

# %% [markdown]
# ## 5.4. combine trained_img L & content_img a,b channel

# %%
trained_luminance = trained_lab[:, :, 0]
content_ab = content_lab[:, :, 1:]

combined_lab = np.zeros_like(trained_lab)
combined_lab[:, :, 0] = trained_luminance
combined_lab[:, :, 1:] = content_ab

postprocessed_img = lab2rgb(combined_lab)
postprocessed_img = Image.fromarray((postprocessed_img * 255.0).astype(np.uint8))

# %% [markdown]
# ## 5.5. visualize

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(untransform(required_noise_feature_map.squeeze(0)))
plt.title("Before Postprocess: noise_img")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(postprocessed_img)
plt.title("After Postprocess: noise_img")
plt.axis("off")

plt.tight_layout()
plt.show()
